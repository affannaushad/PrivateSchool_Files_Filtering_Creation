# %%
import pandas as pd
df = pd.read_csv('concisedfile.csv')

df = df.rename(columns={'Course': 'Course.0', 'End Date': 'End Date.0'})

filtered_df = pd.DataFrame(columns=['Name','Course', 'End Date'])

for i in range(24):  
    a = df[['Name', f'Course.{i}', f'End Date.{i}']] 
    a.drop(0, axis = 0, inplace=True)
    result=(a[a[f'End Date.{i}'] == '2023-11'])
    result = result.rename(columns={f'Course.{i}': 'Course', f'End Date.{i}': 'End Date'})
    filtered_df = filtered_df.append(result, ignore_index=True)

filtered_df.sort_values(['Course'], ascending=True,inplace=True)
filtered_df.set_index('Course', inplace=True)
filtered_df.loc['ESLEO'].head(20)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                  Name End Date
# Course
# ESLEO          Luo Yu  2023-11
# ESLEO      Yangxin Xu  2023-11
# ESLEO      Junyi Wang  2023-11
# ESLEO     Zheng Fanya  2023-11
# ESLEO         Yu Yang  2023-11
# ESLEO       Kaiwen Ye  2023-11
# ESLEO       Zhihui Ye  2023-11
# ESLEO       Wenwen Li  2023-11
# ESLEO      Minghui Li  2023-11
# ESLEO      Runze Xiao  2023-11
# ESLEO       Ziyi Yang  2023-11
# ESLEO       Zheng Wan  2023-11
# ESLEO   Jiaming Zhang  2023-11
# ESLEO        Zheng Wu  2023-11
# ESLEO     Bangyu Wang  2023-11
# ESLEO      Shixun Zhu  2023-11
# ESLEO       Ziqi Tang  2023-11
# ESLEO      Siqin Yuan  2023-11
# ESLEO       Anqi Tong  2023-11
# ESLEO         Le Chen  2023-11
